# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import subprocess
import sys

# %%
from scipy.optimize import bisect

# %%
list_t = np.arange(0,41,1)
list_H=np.arange(1,4.5,0.5)
list_H2=np.arange(1,4.,0.5)+0.2
#list_H3=np.array([2.75, 2.8, 2.85, 2.9, 2.95])
#list_H=np.sort(np.concatenate((list_H, list_H2, list_H3)))
list_H=np.sort(np.concatenate((list_H, list_H2)))
mat_m={}
for H in list_H:
    mat_m[H]={}
    for t in list_t:
        mat_m[H][t]=np.loadtxt('critical_rhof/H%s/f_m_t%d.dat'%(str(H),t))

# %%
pd.DataFrame(mat_m[H][list_t[t]])
# Out:
#           0         1         2         3         4         5         6   \
# 0   0.957504  0.957504  0.957504  0.957504  0.957504  0.957504  0.957504
# 1   0.957504  0.957504  0.957504  0.957504  0.957504  0.957504  0.957504
# 2   0.957504  0.957504  0.957504  0.957504  0.957504  0.957504  0.957504
# 3   0.957504  0.957504  0.957504  0.957504  0.957504  0.957504  0.957504
# 4   0.957504  0.957504  0.957504  0.957504  0.957504  0.957504  0.957504
# ..       ...       ...       ...       ...       ...       ...       ...
# 85  0.957504  0.957504  0.957504  0.957504  0.957504  0.957504  0.957504
# 86  0.957504  0.957504  0.957504  0.957504  0.957504  0.957504  0.957504
# 87  0.957504  0.957504  0.957504  0.957504  0.957504  0.957504  0.957504
# 88  0.957504  0.957504  0.957504  0.957504  0.957504  0.957504  0.957504
# 89  0.957504  0.957504  0.957504  0.957504  0.957504  0.957504  0.957504
#
#           7         8         9   ...        80        81        82        83  \
# 0   0.957504  0.957504  0.957504  ...  0.957504  0.957504  0.957504  0.957504
# 1   0.957504  0.957504  0.957504  ...  0.957504  0.957504  0.957504  0.957504
# 2   0.957504  0.957504  0.957504  ...  0.957504  0.957504  0.957504  0.957504
# 3   0.957504  0.957504  0.957504  ...  0.957504  0.957504  0.957504  0.957504
# 4   0.957504  0.957504  0.957504  ...  0.957504  0.957504  0.957504  0.957504
# ..       ...       ...       ...  ...       ...       ...       ...       ...
# 85  0.957504  0.957504  0.957504  ...  0.957504  0.957504  0.957504  0.957504
# 86  0.957504  0.957504  0.957504  ...  0.957504  0.957504  0.957504  0.957504
# 87  0.957504  0.957504  0.957504  ...  0.957504  0.957504  0.957504  0.957504
# 88  0.957504  0.957504  0.957504  ...  0.957504  0.957504  0.957504  0.957504
# 89  0.957504  0.957504  0.957504  ...  0.957504  0.957504  0.957504  0.957504
#
#           84        85        86        87        88        89
# 0   0.957504  0.957504  0.957504  0.957504  0.957504  0.957504
# 1   0.957504  0.957504  0.957504  0.957504  0.957504  0.957504
# 2   0.957504  0.957504  0.957504  0.957504  0.957504  0.957504
# 3   0.957504  0.957504  0.957504  0.957504  0.957504  0.957504
# 4   0.957504  0.957504  0.957504  0.957504  0.957504  0.957504
# ..       ...       ...       ...       ...       ...       ...
# 85  0.957504  0.957504  0.957504  0.957504  0.957504  0.957504
# 86  0.957504  0.957504  0.957504  0.957504  0.957504  0.957504
# 87  0.957504  0.957504  0.957504  0.957504  0.957504  0.957504
# 88  0.957504  0.957504  0.957504  0.957504  0.957504  0.957504
# 89  0.957504  0.957504  0.957504  0.957504  0.957504  0.957504
#
# [90 rows x 90 columns]

# %%
t=-1
print(list_t[t])
for H in list_H:
    
    plt.matshow(mat_m[H][list_t[t]], cmap='viridis')
#plt.matshow(mat_m0.T, cmap='viridis')
    plt.title(r"$H=%.2f$"%H)
#     plt.xlim(0,10)
#     plt.ylim(0,10)

    plt.colorbar()
# Out:
# 40

# %%
for H in list_H:
    plt.plot([np.mean(mat_m[H][list_t[t]]<0) for t in range(40)], '-', label=H)
    plt.legend()

# %%
def FluctWins(rhof, beta, D, dt, ds):
    print(beta, D, rhof)
    with open('f_input.dat', 'w') as f:
        f.write('ncpu = 9 nby_box = 3 tgap = 11000 tmax = 100 dt = %f lx = 180 ly = 180 ds = %f rhol = 1 beta = %f v = 1 D = %f gamma = 1 rhof = %f'%(dt, ds, beta, D, rhof))
        
    bashCommand = 'mpirun -np 9 ./solve_PDEs_2d > f_m0.dat'
    popen = subprocess.Popen(bashCommand, stdout=subprocess.PIPE,shell=True)
    popen.wait()
    output = popen.stdout.read()
    return(np.loadtxt('f_m0.dat'))

# %%
vec_beta=np.linspace(1.1, 3, 10)
D=1
chi=[]
for beta in vec_beta:
    chi.append(bisect(FluctWins, 1, 20, args=(beta,D, 0.05, 1), xtol=1e-2))
# Out:
# 1.1 1.0
# 1.1 20.0
# 1.1 10.5
# 1.1 15.25
# 1.1 17.625
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-cefdbe383bac> in <module>
#       3 chi=[]
#       4 for beta in vec_beta:
# ----> 5     chi.append(bisect(FluctWins, 1, 20, args=(beta,D, 0.05, 1), xtol=1e-2))
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/optimize/zeros.py in bisect(f, a, b, args, xtol, rtol, maxiter, full_output, disp)
#     551     if rtol < _rtol:
#     552         raise ValueError("rtol too small (%g < %g)" % (rtol, _rtol))
# --> 553     r = _zeros._bisect(f, a, b, xtol, rtol, maxiter, args, full_output, disp)
#     554     return results_c(full_output, r)
#     555
#
# <ipython-input-4-2bbaa1cb883c> in FluctWins(rhof, beta, D, dt, ds)
#       6     bashCommand = 'mpirun -np 9 ./solve_PDEs_2d > f_m0.dat'
#       7     popen = subprocess.Popen(bashCommand, stdout=subprocess.PIPE,shell=True)
# ----> 8     popen.wait()
#       9     output = popen.stdout.read()
#      10     return(np.loadtxt('f_m0.dat'))
#
# ~/anaconda3/lib/python3.7/subprocess.py in wait(self, timeout)
#    1017             endtime = _time() + timeout
#    1018         try:
# -> 1019             return self._wait(timeout=timeout)
#    1020         except KeyboardInterrupt:
#    1021             # https://bugs.python.org/issue25942
#
# ~/anaconda3/lib/python3.7/subprocess.py in _wait(self, timeout)
#    1651                         if self.returncode is not None:
#    1652                             break  # Another thread waited.
# -> 1653                         (pid, sts) = self._try_wait(0)
#    1654                         # Check the pid and loop as waitpid has been known to
#    1655                         # return 0 even without WNOHANG in odd situations.
#
# ~/anaconda3/lib/python3.7/subprocess.py in _try_wait(self, wait_flags)
#    1609             """All callers to this function MUST hold self._waitpid_lock."""
#    1610             try:
# -> 1611                 (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1612             except ChildProcessError:
#    1613                 # This happens if SIGCLD is set to be ignored or waiting
#
# KeyboardInterrupt:

# %%
plt.plot(vec_beta, chi, 'o-')

# %%
vec_beta=np.linspace(1.1, 3, 20)
D=1
dt=0.01
ds=0.5

Hcrit={}
Hcrit[D]={}
for beta in vec_beta:
    Hcrit[D][beta]=bisect(FluctWins, 1, 20, args=(beta,D,dt, ds), xtol=1e-1)
# Out:
# 1.1 1.0
# 1.1 20.0
# 1.1 10.5
# 1.1 15.25
# 1.1 17.625
# 1.1 16.4375
# 1.1 17.03125
# 1.1 16.734375
# 1.1 16.5859375
# 1.1 16.66015625
# 1.2000000000000002 1.0
# 1.2000000000000002 20.0
# 1.2000000000000002 10.5
# 1.2000000000000002 5.75
# 1.2000000000000002 8.125
# 1.2000000000000002 9.3125
# 1.2000000000000002 8.71875
# 1.2000000000000002 9.015625
# 1.2000000000000002 8.8671875
# 1.2000000000000002 8.79296875
# 1.3 1.0
# 1.3 20.0
# 1.3 10.5
# 1.3 5.75
# 1.3 8.125
# 1.3 6.9375
# 1.3 6.34375
# 1.3 6.046875
# 1.3 5.8984375
# 1.3 5.97265625
# 1.4000000000000001 1.0
# 1.4000000000000001 20.0
# 1.4000000000000001 10.5
# 1.4000000000000001 5.75
# 1.4000000000000001 3.375
# 1.4000000000000001 4.5625
# 1.4000000000000001 5.15625
# 1.4000000000000001 4.859375
# 1.4000000000000001 4.7109375
# 1.4000000000000001 4.63671875
# 1.5 1.0
# 1.5 20.0
# 1.5 10.5
# 1.5 5.75
# 1.5 3.375
# 1.5 4.5625
# 1.5 3.96875
# 1.5 3.671875
# 1.5 3.8203125
# 1.5 3.89453125
# 1.6 1.0
# 1.6 20.0
# 1.6 10.5
# 1.6 5.75
# 1.6 3.375
# 1.6 4.5625
# 1.6 3.96875
# 1.6 3.671875
# 1.6 3.5234375
# 1.6 3.44921875
# 1.7000000000000002 1.0
# 1.7000000000000002 20.0
# 1.7000000000000002 10.5
# 1.7000000000000002 5.75
# 1.7000000000000002 3.375
# 1.7000000000000002 2.1875
# 1.7000000000000002 2.78125
# 1.7000000000000002 3.078125
# 1.7000000000000002 3.2265625
# 1.7000000000000002 3.15234375
# 1.8 1.0
# 1.8 20.0
# 1.8 10.5
# 1.8 5.75
# 1.8 3.375
# 1.8 2.1875
# 1.8 2.78125
# 1.8 3.078125
# 1.8 2.9296875
# 1.8 3.00390625
# 1.9 1.0
# 1.9 20.0
# 1.9 10.5
# 1.9 5.75
# 1.9 3.375
# 1.9 2.1875
# 1.9 2.78125
# 1.9 2.484375
# 1.9 2.6328125
# 1.9 2.70703125
# 2.0 1.0
# 2.0 20.0
# 2.0 10.5
# 2.0 5.75
# 2.0 3.375
# 2.0 2.1875
# 2.0 2.78125
# 2.0 2.484375
# 2.0 2.6328125
# 2.0 2.55859375
# 2.1 1.0
# 2.1 20.0
# 2.1 10.5
# 2.1 5.75
# 2.1 3.375
# 2.1 2.1875
# 2.1 2.78125
# 2.1 2.484375
# 2.1 2.6328125
# 2.1 2.55859375
# 2.2 1.0
# 2.2 20.0
# 2.2 10.5
# 2.2 5.75
# 2.2 3.375
# 2.2 2.1875
# 2.2 2.78125
# 2.2 2.484375
# 2.2 2.3359375
# 2.2 2.41015625
# 2.3 1.0
# 2.3 20.0
# 2.3 10.5
# 2.3 5.75
# 2.3 3.375
# 2.3 2.1875
# 2.3 2.78125
# 2.3 2.484375
# 2.3 2.3359375
# 2.3 2.26171875
# 2.4 1.0
# 2.4 20.0
# 2.4 10.5
# 2.4 5.75
# 2.4 3.375
# 2.4 2.1875
# 2.4 2.78125
# 2.4 2.484375
# 2.4 2.3359375
# 2.4 2.26171875
# 2.5 1.0
# 2.5 20.0
# 2.5 10.5
# 2.5 5.75
# 2.5 3.375
# 2.5 2.1875
# 2.5 1.59375
# 2.5 1.890625
# 2.5 2.0390625
# 2.5 2.11328125
# 2.5999999999999996 1.0
# 2.5999999999999996 20.0
# 2.5999999999999996 10.5
# 2.5999999999999996 5.75
# 2.5999999999999996 3.375
# 2.5999999999999996 2.1875
# 2.5999999999999996 1.59375
# 2.5999999999999996 1.890625
# 2.5999999999999996 2.0390625
# 2.5999999999999996 2.11328125
# 2.7 1.0
# 2.7 20.0
# 2.7 10.5
# 2.7 5.75
# 2.7 3.375
# 2.7 2.1875
# 2.7 1.59375
# 2.7 1.890625
# 2.7 2.0390625
# 2.7 2.11328125
# 2.8 1.0
# 2.8 20.0
# 2.8 10.5
# 2.8 5.75
# 2.8 3.375
# 2.8 2.1875
# 2.8 1.59375
# 2.8 1.890625
# 2.8 2.0390625
# 2.8 2.11328125
# 2.9 1.0
# 2.9 20.0
# 2.9 10.5
# 2.9 5.75
# 2.9 3.375
# 2.9 2.1875
# 2.9 1.59375
# 2.9 1.890625
# 2.9 2.0390625
# 2.9 1.96484375
# 3.0 1.0
# 3.0 20.0
# 3.0 10.5
# 3.0 5.75
# 3.0 3.375
# 3.0 2.1875
# 3.0 1.59375
# 3.0 1.890625
# 3.0 2.0390625
# 3.0 1.96484375

# %%
plt.plot(vec_beta, [Hcrit[D][beta] for beta in vec_beta], 'o-')

# %%
vec_D=np.linspace(0.5, 3, 20)
beta=2
dt=0.01
ds=0.5

Hcrit_D={}
for D in vec_D:
    Hcrit_D[D]=bisect(FluctWins, 1, 20, args=(beta,D,dt, ds), xtol=1e-2)
# Out:
# 2 0.5 1.0
# 2 0.5 20.0
# 2 0.5 10.5
# 2 0.5 5.75
# 2 0.5 3.375
# 2 0.5 2.1875
# 2 0.5 1.59375
# 2 0.5 1.296875
# 2 0.5 1.1484375
# 2 0.5 1.07421875
# 2 0.5 1.111328125
# 2 0.5 1.0927734375
# 2 0.5 1.08349609375
# 2 0.631578947368421 1.0
# 2 0.631578947368421 20.0
# 2 0.631578947368421 10.5
# 2 0.631578947368421 5.75
# 2 0.631578947368421 3.375
# 2 0.631578947368421 2.1875
# 2 0.631578947368421 1.59375
# 2 0.631578947368421 1.296875
# 2 0.631578947368421 1.4453125
# 2 0.631578947368421 1.37109375
# 2 0.631578947368421 1.408203125
# 2 0.631578947368421 1.4267578125
# 2 0.631578947368421 1.41748046875
# 2 2.473684210526316 10.9453125
# 2 2.473684210526316 11.01953125
# 2 2.473684210526316 11.056640625
# 2 2.473684210526316 11.0751953125
# 2 2.473684210526316 11.06591796875
# 2 2.6052631578947367 1.0
# 2 2.6052631578947367 20.0
# 2 2.6052631578947367 10.5
# 2 2.6052631578947367 15.25
# 2 2.6052631578947367 12.875
# 2 2.6052631578947367 11.6875
# 2 2.6052631578947367 12.28125
# 2 2.6052631578947367 11.984375
# 2 2.6052631578947367 12.1328125
# 2 2.6052631578947367 12.05859375
# 2 2.6052631578947367 12.095703125
# 2 2.6052631578947367 12.0771484375
# 2 2.6052631578947367 12.08642578125
# 2 2.736842105263158 1.0
# 2 2.736842105263158 20.0
# 2 2.736842105263158 10.5
# 2 2.736842105263158 15.25
# 2 2.736842105263158 12.875
# 2 2.736842105263158 14.0625
# 2 2.736842105263158 13.46875
# 2 2.736842105263158 13.171875
# 2 2.736842105263158 13.0234375
# 2 2.736842105263158 13.09765625
# 2 2.736842105263158 13.134765625
# 2 2.736842105263158 13.1533203125
# 2 2.736842105263158 13.14404296875
# 2 2.8684210526315788 1.0
# 2 2.8684210526315788 20.0
# 2 2.8684210526315788 10.5
# 2 2.8684210526315788 15.25
# 2 2.8684210526315788 12.875
# 2 2.8684210526315788 14.0625
# 2 2.8684210526315788 14.65625
# 2 2.8684210526315788 14.359375
# 2 2.8684210526315788 14.2109375
# 2 2.8684210526315788 14.28515625
# 2 2.8684210526315788 14.248046875
# 2 2.8684210526315788 14.2294921875
# 2 2.8684210526315788 14.23876953125
# 2 3.0 1.0
# 2 3.0 20.0
# 2 3.0 10.5
# 2 3.0 15.25
# 2 3.0 17.625
# 2 3.0 16.4375
# 2 3.0 15.84375
# 2 3.0 15.546875
# 2 3.0 15.3984375
# 2 3.0 15.32421875
# 2 3.0 15.361328125
# 2 3.0 15.3798828125
# 2 3.0 15.37060546875

# %%
fig_width_pt = 246  # Get this from LaTeX using \showthe\columnwidth
                      # For PRL columnwidth is 246pt.
golden_mean = (np.sqrt(5)+1.0)/2.0         # Aesthetic ratio

fig_height_pt = fig_width_pt/golden_mean
inches_per_pt = 1.0/72.27               # Convert pt to inch
fig_width = fig_width_pt*inches_per_pt  # width in inches
fig_height = fig_height_pt*inches_per_pt      # height in inches
fig_size =  [fig_width,fig_height]
params = {'backend': 'ps',
          'axes.labelsize': 10,
          'font.size': 10,
          'xtick.labelsize': 7,
          'xtick.direction': 'out',
          'ytick.labelsize': 7,
          'ytick.direction': 'out',
          'ytick.major.pad': 1,
          'xtick.major.pad': 1,
          'text.usetex': True,
          'figure.figsize': fig_size,
          'legend.frameon': False,
          'legend.fancybox': False}
plt.rcParams.update(params)

# %%
import matplotlib as mpl
mpl.rcParams['axes.prop_cycle'] = mpl.cycler(color=[plt.get_cmap('Dark2')(a) for a in np.linspace(0,1,9)])

# %%
plt.plot(vec_D,[ Hcrit_D[D] for D in vec_D], 'o-')

plt.xlim((0.5,3))


plt.xlabel(r'$D$', rotation=0, labelpad=-20, x=0.97)
plt.ylabel(r'$\rho_{fluct}$', rotation=0, labelpad=-28, y=0.9)

plt.tight_layout(pad=0.1)

plt.savefig('aster_prof.pdf', dpi=400);

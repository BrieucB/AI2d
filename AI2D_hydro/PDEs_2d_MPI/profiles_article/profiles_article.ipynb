# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
list_t=[2000, 4000, 6000, 8000, 10000]
mat_m={}
for t in list_t:
    mat_m[t]=np.loadtxt('beta2.0/f_m_t%d.dat'%(t))

# %%
for t in list_t:
    plt.matshow(mat_m[t], cmap='viridis')

# %%
for t in list_t:
    plt.plot(mat_m[t][1000,:])

plt.ylim(-5.1,-4.8)
# Out:
# (-5.1, -4.8)

# %%
plt.plot(mat_m[6000][1100,:])
plt.plot(mat_m[6000][1000,:])
plt.plot(mat_m[6000][900,:])

plt.ylim(-5.1,-4.8)
# Out:
# (-5.1, -4.8)

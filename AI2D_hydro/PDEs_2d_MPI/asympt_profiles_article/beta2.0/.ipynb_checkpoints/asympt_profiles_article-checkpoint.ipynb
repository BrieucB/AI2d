# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
list_t=np.arange(10000,41000,10000)

# %%
lx=22000 
ly = 11000

# %%
m_t={}
for t in list_t:
    m_t[t]=pd.read_csv("f_m_t%d.dat"%d, )

# %%
data=pd.read_csv("f_m_t40000.dat", names=np.arange(lx), sep=' ', index_col=False, dtype=np.float64)

# %%
data
# Out:
#           0         1         2         3         4         5         6      \
# 0      0.957504  0.957504  0.957504  0.957504  0.957504  0.957504  0.957504
# 1      0.957504  0.957504  0.957504  0.957504  0.957504  0.957504  0.957504
# 2      0.957504  0.957504  0.957504  0.957504  0.957504  0.957504  0.957504
# 3      0.957504  0.957504  0.957504  0.957504  0.957504  0.957504  0.957504
# 4      0.957504  0.957504  0.957504  0.957504  0.957504  0.957504  0.957504
# ...         ...       ...       ...       ...       ...       ...       ...
# 10995  0.957504  0.957504  0.957504  0.957504  0.957504  0.957504  0.957504
# 10996  0.957504  0.957504  0.957504  0.957504  0.957504  0.957504  0.957504
# 10997  0.957504  0.957504  0.957504  0.957504  0.957504  0.957504  0.957504
# 10998  0.957504  0.957504  0.957504  0.957504  0.957504  0.957504  0.957504
# 10999  0.957504  0.957504  0.957504  0.957504  0.957504  0.957504  0.957504
#
# ...

# %%
plt.matshow(data)

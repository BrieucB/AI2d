# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Pre-destab profiles

# %%
list_D=[0.005, 0.01, 0.02, 0.04, 0.06, 0.08, 0.10, 0.12, 0.14, 0.16, 0.18, 0.20, 0.22, 0.24, 0.26, 0.28, 0.3, 0.32, 0.34, 0.36, 0.38, 0.4]

# %%
prof_destab_9={}
prof_destab_1={}


for D in list_D:
    try:
        prof_destab_9[D]=pd.read_csv('t_destab_D_avg_m/D%s/f_profiles.dat'%str(D), sep=' ', names=np.arange(600), index_col=False)
    except: 
        print(9,D)
        
for D in list_D:
    try:
        prof_destab_1[D]=pd.read_csv('../1nei/t_destab_D/D%s/f_profiles.dat'%str(D), sep=' ', names=np.arange(600), index_col=False)

    except: 
        print(1,D)
# Out:
# 9 0.38
# 9 0.4
# 1 0.32
# 1 0.34
# 1 0.36
# 1 0.38
# 1 0.4

# %%
t_destab_9[0.26]
# Out:
# array(39545.64)

# %%
k=3
D=0.24
plt.matshow(prof_destab_9[D].values[k*300:(k+1)*300,:])

# %%
plt.matshow(prof_destab_9[0.34].values[300:600,:])

# %%
plt.matshow(prof_destab_9[0.34].values[600:900,:])
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-884-56b787326c46> in <module>
# ----> 1 plt.matshow(prof_destab_9[0.34].values[600:900,:])
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in matshow(A, fignum, **kwargs)
#    2186         # Extract actual aspect ratio of array and make appropriately sized
#    2187         # figure.
# -> 2188         fig = figure(fignum, figsize=figaspect(A))
#    2189         ax = fig.add_axes([0.15, 0.09, 0.775, 0.775])
#    2190     im = ax.matshow(A, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in figaspect(arg)
#    2750
#    2751     # New size for the figure, keeping the aspect ratio of the caller
# -> 2752     newsize = np.array((fig_height / arr_ratio, fig_height))
#    2753
#    2754     # Sanity checks, don't drop either dimension below figsize_min
#
# ZeroDivisionError: float division by zero

# %%
plt.matshow(prof_destab_9[0.08].values[:300,:])

# %%
t_destab_1[0.3]
# Out:
# array([ 200414.82,  792608.04, 1542423.24,  534098.87, 1137388.49,
#         920771.13, 1729522.78,  697074.55,  694811.24,  302708.73,
#         152119.66, 1361504.39,  361669.28,  265117.96,  176889.78,
#         773254.31,  245031.  ,  820076.34,  750742.51,   44308.53,
#         761123.71,  901783.44,   86380.56,  286642.5 ,  512998.56,
#          66319.35,  125115.55,  575190.19, 1302967.66,   91787.03,
#         377174.98,  162467.4 ,  202999.96,  193861.1 ,  610775.34,
#         127441.01, 1054284.48,  132835.29,  324338.91,   52073.32,
#         430706.1 ,  198707.36,  195887.06,   83873.84,    4025.84,
#         374115.34,   53491.29,  931587.73,  342561.04,  170525.86])

# %% [markdown]
# # Destab times

# %%
list_D=[0.005, 0.01, 0.02, 0.04, 0.06, 0.08, 0.10, 0.12, 0.14, 0.16, 0.18, 0.20, 0.22, 0.24, 0.26, 0.28, 0.3, 0.32, 0.34, 0.36, 0.38, 0.4]

# %%
t_destab_9={}
mean_t_9=[]
std_t_9=[]

t_destab_1={}
mean_t_1=[]
std_t_1=[]


for D in list_D:
    try:
        t_destab_9[D]=np.loadtxt('t_destab_D_avg_m/D%s/f_td.dat'%str(D))
        mean_t_9.append(np.mean(t_destab_9[D]))
        std_t_9.append(np.std(t_destab_9[D]))
        print(D, t_destab_9[D].shape[0])
    except: 
        print(9,D)
        
for D in list_D:
    try:
        t_destab_1[D]=np.loadtxt('../1nei/t_destab_D/D%s/f_td.dat'%str(D))
        mean_t_1.append(np.mean(t_destab_1[D]))
        std_t_1.append(np.std(t_destab_1[D]))
    except: 
        mean_t_1.append(np.nan)
        std_t_1.append(np.nan)

        print(1,D)
# Out:
# 0.005 50
# 0.01 50
# 0.02 50
# 0.04 50
# 0.06 50
# 0.08 50
# 0.1 50
# 0.12 50
# 0.14 50
# 0.16 50
# 0.18 50
# 0.2 0
# 0.22 18
# 0.24 4
# 9 0.26
# 0.28 12
# 0.3 3
# 0.32 2
# 0.34 2
# 0.36 0
# 9 0.38
# 9 0.4
# 1 0.32
# 1 0.34
# 1 0.36
# 1 0.38
# 1 0.4
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: UserWarning: loadtxt: Empty input file: "t_destab_D_avg_m/D0.2/f_td.dat"
#   if sys.path[0] == '':
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: UserWarning: loadtxt: Empty input file: "t_destab_D_avg_m/D0.36/f_td.dat"
#   if sys.path[0] == '':

# %%
for tD in t_destab_1:
    print(tD)
    print(tD.shape[0] )
# Out:
# 0.005
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-912-395e19b32c0d> in <module>
#       1 for tD in t_destab_1:
#       2     print(tD)
# ----> 3     print(tD.shape[0] )
#
# AttributeError: 'float' object has no attribute 'shape'

# %%
#plt.errorbar(list_D, mean_t_9, yerr=3*np.array(std_t_9)/np.sqrt([t_destab_9[D].shape[0] if t_destab_9[D].shape!=() else 1 for D in list_D]), fmt='o', label='9 boxes')
plt.errorbar(list(t_destab_1), mean_t_1[:len(list(t_destab_1))], yerr=3*np.array(std_t_1[:len(list(t_destab_1))])/np.sqrt([t_destab_1[tD].shape[0] if t_destab_1[tD].shape!=() else 1 for tD in t_destab_1]), fmt='o', label='1 box')
plt.legend()
plt.yscale('log')


absD=np.linspace(0.005, 0.22, 100)

#plt.plot(absD, 80*np.exp(45*absD))

# %%
plt.errorbar(list(t_destab_9), mean_t_9, yerr=3*np.array(std_t_9)/np.sqrt([t_destab_9[tD].shape[0] if t_destab_9[tD].shape!=() else 1 for tD in t_destab_9]), fmt='o', label='9 boxes')
#plt.errorbar(list(t_destab_1), mean_t_1[:len(list(t_destab_1))], yerr=3*np.array(std_t_1[:len(list(t_destab_1))])/np.sqrt([t_destab_1[tD].shape[0] if t_destab_1[tD].shape!=() else 1 for tD in t_destab_1]), fmt='o', label='1 box')
plt.legend()
plt.yscale('log')


absD=np.linspace(0.005, 0.22, 100)

#plt.plot(absD, 80*np.exp(45*absD))

# %%
D=0.24
t_destab_9[D]
# Out:
# array([2072337.79,   62863.92, 2309898.39,  810465.42])

# %%
D=0.3
sns.distplot(t_destab_1[0.22])
plt.yscale('log')

# %%
absD=np.linspace(0.005, 0.2, 100)
plt.semilogy(absD, np.exp((fitLogi(absD, L=2.4, k=50, x0=0.1, t0=0))))

# %%
def Logi(x, L, k, x0, t0):
    #print(x, L, k, x0)
    return(L/(1+np.exp(-k*(x-x0))+t0))

# %%
def fitLogi(x, L, k, x0, t0):
    #print(x, L, k, x0)
    return(t0+np.exp(L/(1+np.exp(-k*(x-x0)))))

# %%
from scipy.optimize import curve_fit

# %%
mean_t_1=np.array(mean_t_1)
list_D=np.array(list_D)

# %%
popt, pcov = curve_fit(fitLogi, list_D[~np.isnan(mean_t_1)], mean_t_1[~np.isnan(mean_t_1)], p0=[2.4, 50, 0.1, 0])
# Out:
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: overflow encountered in exp
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
popt
# Out:
# array([ 7.4733897 ,  2.75496439, -0.08144689, -0.88198435])

# %%
mean_t_1[~np.isnan(mean_t_1)]
# Out:
# array([8.95586000e+01, 9.55958000e+01, 1.10073800e+02, 1.92737000e+02,
#        5.12698200e+02, 2.96357240e+03, 1.18470874e+04, 5.11576988e+04,
#        1.16891264e+05, 1.68298985e+05, 1.83759147e+05])

# %%
 list_D[~np.isnan(mean_t_1)]
# Out:
# array([0.005, 0.01 , 0.02 , 0.04 , 0.06 , 0.08 , 0.1  , 0.12 , 0.14 ,
#        0.16 , 0.18 ])

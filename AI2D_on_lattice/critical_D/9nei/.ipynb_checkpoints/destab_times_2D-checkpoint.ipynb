# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

# %% [markdown]
# # Pre-destab profiles

# %%
list_D=[0.005, 0.01, 0.02, 0.04, 0.06, 0.08, 0.10, 0.12, 0.14, 0.16, 0.18, 0.20, 0.22, 0.24, 0.26, 0.28, 0.3, 0.32, 0.34, 0.36, 0.38, 0.4]

# %%
prof_destab_9={}

for D in list_D:
    try:
        prof_destab_9[D]=pd.read_csv('t_destab_D_v3/D%s/f_profiles.dat'%str(D), sep=' ', names=np.arange(600), index_col=False)
        print(D, prof_destab_9[D].shape[0]//300)
    except: 
        pass
# Out:
# 0.005 50
# 0.01 50
# 0.02 50
# 0.04 50
# 0.06 50
# 0.08 50
# 0.1 50
# 0.12 50
# 0.14 50
# 0.16 50
# 0.18 30
# 0.2 25
# 0.22 13
# 0.28 2
# 0.3 3
# 0.32 3
# 0.34 0
# 0.36 1
# 0.38 1
# 0.4 0

# %%
prof_destab_1={}
for D in list_D:
    try:
        prof_destab_1[D]=pd.read_csv('../1nei/t_destab_D_v3/D%s/f_profiles.dat'%str(D), sep=' ', names=np.arange(200), index_col=False)
        print(D, prof_destab_1[D].shape[0]//100)
    except: 
        pass
# Out:
# 0.005 50
# 0.01 50
# 0.02 50
# 0.04 50
# 0.06 50
# 0.08 50
# 0.1 50
# 0.12 50
# 0.14 50
# 0.16 50
# 0.18 50
# 0.2 50
# 0.22 42
# 0.28 33
# 0.3 21
# 0.32 50
# 0.34 44
# 0.36 44
# 0.38 48
# 0.4 50

# %%
k=20
D=0.2
V=5#np.max(prof_destab_1[D].values[k*100:(k+1)*100,:])
plt.matshow(prof_destab_1[D].values[k*100:(k+1)*100,:], cmap='PiYG', vmin=-V, vmax=V)
plt.colorbar()

# %%
plt.plot(prof_destab_1[D].values[k*100:(k+1)*100][np.argmin(np.sum(prof_destab_1[D].values[k*100:(k+1)*100,:],axis=1)),:])
plt.plot(np.mean(prof_destab_1[D].values[k*100:(k+1)*100], axis=0))

# %%
np.sum(prof_destab_1[D].values[k*100:(k+1)*100][14,:])
# Out:
# 196.0

# %%
# Out:
# 73

# %%
plt.plot(np.sum(prof_destab_1[D].values[k*100:(k+1)*100,:],axis=1), 'o-')

# %%
list_D=[0.005, 0.01, 0.02, 0.04, 0.06, 0.08, 0.10, 0.12, 0.14, 0.16, 0.18, 0.20, 0.22, 0.24, 0.26, 0.28, 0.3, 0.32, 0.34, 0.36, 0.38, 0.4]

# %%
k=2
D=0.32
V=np.max(prof_destab_9[D].values[k*300:(k+1)*300,:])
plt.matshow(prof_destab_9[D].values[k*300:(k+1)*300,:], cmap='PiYG', vmin=-V, vmax=V)
plt.colorbar()

# %%
plt.plot(prof_destab_9[D].values[k*300:(k+1)*300][np.argmin(np.sum(prof_destab_9[D].values[k*300:(k+1)*300,:],axis=1)),:])
plt.plot(np.mean(prof_destab_9[D].values[k*300:(k+1)*300], axis=0))

# %%
plt.plot(np.sum(prof_destab_9[D].values[k*300:(k+1)*300,:],axis=1))

# %% [markdown]
# # Destab times

# %%
list_D=[0.005, 0.01, 0.02, 0.04, 0.06, 0.08, 0.10, 0.12, 0.14, 0.16, 0.18, 0.20, 0.22, 0.28, 0.3, 0.32, 0.34, 0.36, 0.38, 0.4]

# %%
for D in list_D:
    print(D, end=' ')
# Out:
# 0.005 0.01 0.02 0.04 0.06 0.08 0.1 0.12 0.14 0.16 0.18 0.2 0.22 0.28 0.3 0.32 0.34 0.36 0.38 0.4

# %%
t_destab_9={}
mean_t_9=[]
std_t_9=[]

t_destab_1={}
mean_t_1=[]
std_t_1=[]


for D in list_D:
    try:
        t_destab_9[D]=np.loadtxt('t_destab_D_v3/D%s/f_td.dat'%str(D))
        mean_t_9.append(np.mean(t_destab_9[D]))
        std_t_9.append(np.std(t_destab_9[D]))
        print(D, t_destab_9[D].shape[0])
    except: 
        print(9,D)
        
for D in list_D:
    try:
        t_destab_1[D]=pd.read_csv('../1nei/t_destab_D_v3/D%s/f_td.dat'%str(D)).values
        mean_t_1.append(np.mean(t_destab_1[D]))
        std_t_1.append(np.std(t_destab_1[D]))
    except: 
        mean_t_1.append(np.nan)
        std_t_1.append(np.nan)

        print(1,D)
# Out:
# 0.005 50
# 0.01 50
# 0.02 50
# 0.04 50
# 0.06 50
# 0.08 50
# 0.1 50
# 0.12 50
# 0.14 50
# 0.16 50
# 0.18 30
# 0.2 25
# 0.22 13
# 0.28 2
# 0.3 3
# 0.32 3
# 0.34 0
# 9 0.36
# 9 0.38
# 0.4 0
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: UserWarning: loadtxt: Empty input file: "t_destab_D_v3/D0.34/f_td.dat"
#   if sys.path[0] == '':
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:217: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:186: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:209: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: UserWarning: loadtxt: Empty input file: "t_destab_D_v3/D0.4/f_td.dat"
#   if sys.path[0] == '':

# %%
plt.plot(list_D, mean_t_1, 'o')
plt.legend()
plt.yscale('log')
# Out:
# No handles with labels found to put in legend.

# %%
plt.plot(list_D, mean_t_9, 'o')
plt.legend()
plt.yscale('log')
# Out:
# No handles with labels found to put in legend.

# %%
plt.errorbar(list_D, mean_t_9, yerr=3*np.array(std_t_9)/np.sqrt([t_destab_9[D].shape[0] if t_destab_9[D].shape!=() else 1 for D in list_D]), fmt='o', label='9 boxes')
#plt.errorbar(list(t_destab_1), mean_t_1[:len(list(t_destab_1))], yerr=3*np.array(std_t_1[:len(list(t_destab_1))])/np.sqrt([t_destab_1[tD].shape[0] if t_destab_1[tD].shape!=() else 1 for tD in t_destab_1]), fmt='o', label='1 box')
plt.semilogy()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-157-5762ef84463c> in <module>
# ----> 1 plt.errorbar(list_D, mean_t_9, yerr=3*np.array(std_t_9)/np.sqrt([t_destab_9[D].shape[0] if t_destab_9[D].shape!=() else 1 for D in list_D]), fmt='o', label='9 boxes')
#       2 #plt.errorbar(list(t_destab_1), mean_t_1[:len(list(t_destab_1))], yerr=3*np.array(std_t_1[:len(list(t_destab_1))])/np.sqrt([t_destab_1[tD].shape[0] if t_destab_1[tD].shape!=() else 1 for tD in t_destab_1]), fmt='o', label='1 box')
#       3 plt.semilogy()
#
# <ipython-input-157-5762ef84463c> in <listcomp>(.0)
# ----> 1 plt.errorbar(list_D, mean_t_9, yerr=3*np.array(std_t_9)/np.sqrt([t_destab_9[D].shape[0] if t_destab_9[D].shape!=() else 1 for D in list_D]), fmt='o', label='9 boxes')
#       2 #plt.errorbar(list(t_destab_1), mean_t_1[:len(list(t_destab_1))], yerr=3*np.array(std_t_1[:len(list(t_destab_1))])/np.sqrt([t_destab_1[tD].shape[0] if t_destab_1[tD].shape!=() else 1 for tD in t_destab_1]), fmt='o', label='1 box')
#       3 plt.semilogy()
#
# KeyError: 0.24

# %%
#plt.errorbar(list(t_destab_9), mean_t_9, yerr=3*np.array(std_t_9)/np.sqrt([t_destab_9[tD].shape[0] if t_destab_9[tD].shape!=() else 1 for tD in t_destab_9]), fmt='o', label='9 boxes')
#plt.errorbar(list(t_destab_1), mean_t_1[:len(list(t_destab_1))], yerr=3*np.array(std_t_1[:len(list(t_destab_1))])/np.sqrt([t_destab_1[tD].shape[0] if t_destab_1[tD].shape!=() else 1 for tD in t_destab_1]), fmt='o', label='1 box')

plt.semilogy(list(t_destab_9), mean_t_9, 'o', label='9-boxes on-lattice')
plt.plot(list_D, mean_t_1, 'o', label='1-box on-lattice')

plt.legend()

plt.xlim(0,0.23)
# plt.ylim(7e1,1e6)
plt.xlabel(r'$D$')
plt.ylabel(r'$\langle \tau \rangle$')
# Out:
# Text(0, 0.5, '$\\langle \\tau \\rangle$')

# %%
list_D_off=[0.005, 0.01, 0.02, 0.04, 0.06, 0.08, 0.10, 0.12, 0.14, 0.16, 0.18, 0.20, 0.22, 0.24, 0.26, 0.28, 0.3, 0.32, 0.34, 0.36, 0.38, 0.4]

path='~/Thesis/AI2D/AI2D_off_lattice/critical_D/runs_v3/'

filename='f_td.dat'

destab_times={}
for D in list_D_off:
    try:
        destab_times[D]=pd.read_csv(path+'D%s/'%str(D)+filename, names=['td'], index_col=False)

    except FileNotFoundError:
        print(D)
# Out:
# 0.24
# 0.26

# %%
plt.semilogy(list(t_destab_9), mean_t_9, 'o', label='9-boxes on-lattice')
plt.plot(list_D, mean_t_1, 'o', label='1-box on-lattice')
plt.plot(list(destab_times), [np.nanmean(destab_times[D].td.values) if len(destab_times[D].td.values)!=0 else np.nan for D in destab_times ], 'o', label='Off-lattice')

plt.legend()

plt.xlim(0,0.23)
# plt.ylim(7e1,1e6)
plt.xlabel(r'$D$')
plt.ylabel(r'$\langle \tau \rangle$')
plt.savefig('destab_band_times_D.pdf')

# %% [markdown]
# # Vertical spreading 1box

# %%
from scipy import ndimage

# %%
def mean_filter(X):
    return((np.roll(X, 1, axis=0)+np.roll(X, -1, axis=0)+np.roll(X, 1, axis=1)+np.roll(X, -1, axis=1)+X)/5)

# %%
D=0.005
k=0
X=prof_destab_1[D].values[k*100:(k+1)*100,:]
V=np.max(X)
plt.matshow(X, cmap='PiYG', vmin=-V, vmax=V)
plt.colorbar()
plt.matshow(mean_filter(X))

# %%
mag_thresh=10

# %%
vertical_sizes_1={}
vertical_sizes_9={}
for D in list_D:
    vertical_sizes_1[D]=[]
    vertical_sizes_9[D]=[]
    for k in range(prof_destab_1[D].shape[0]//100):
        try:
            X=prof_destab_1[D].values[k*100:(k+1)*100,:]
            lab_array, ng = ndimage.label((mean_filter(X)<-mag_thresh), np.ones((3,3)))
            lab, nlab = np.unique(lab_array, return_counts=True)
            X_clust=(lab_array==lab[np.argsort(nlab)[-2]])
            vertical_sizes_1[D].append(np.sum(np.sum(X_clust, axis=1)!=0))
        except:
            pass
        
    for k in range(prof_destab_9[D].shape[0]//300):
        try:
            X=prof_destab_9[D].values[k*300:(k+1)*300,:]
            lab_array, ng = ndimage.label((mean_filter(X)<-2), np.ones((3,3)))
            lab, nlab = np.unique(lab_array, return_counts=True)
            X_clust=(lab_array==lab[np.argsort(nlab)[-2]])
            vertical_sizes_9[D].append(np.sum(np.sum(X_clust, axis=1)!=0))
        except:
            print(9, D, k)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-137-0943ee546d4c> in <module>
#       4     vertical_sizes_1[D]=[]
#       5     vertical_sizes_9[D]=[]
# ----> 6     for k in range(prof_destab_1[D].shape[0]//100):
#       7         try:
#       8             X=prof_destab_1[D].values[k*100:(k+1)*100,:]
#
# KeyError: 0.24

# %%
plt.plot(list(vertical_sizes_9), [np.mean(vertical_sizes_9[D]) for D in vertical_sizes_1], 'o-')
# Out:
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
plt.plot(list(vertical_sizes_1), [np.mean(vertical_sizes_1[D]) for D in vertical_sizes_1], 'o-')
plt.xlim(0,0.2)
plt.xlabel(r'$D$')
plt.ylabel(r'Fluctuation vertical extension (in sites)');
# Out:
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

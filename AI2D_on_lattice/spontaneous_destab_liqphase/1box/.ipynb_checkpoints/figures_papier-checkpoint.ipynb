# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
fig_width_pt = 246  # Get this from LaTeX using \showthe\columnwidth
                      # For PRL columnwidth is 246pt.
golden_mean = (np.sqrt(5)+1.0)/2.0         # Aesthetic ratio

fig_height_pt = fig_width_pt/golden_mean
inches_per_pt = 1.0/72.27               # Convert pt to inch
fig_width = fig_width_pt*inches_per_pt  # width in inches
fig_height = fig_height_pt*inches_per_pt      # height in inches
fig_size =  [fig_width,fig_height]
params = {'backend': 'ps',
          'axes.labelsize': 12,
          'font.size': 12,
          'xtick.labelsize': 10,
          'xtick.direction': 'out',
          'ytick.labelsize': 10,
          'ytick.direction': 'out',
          'ytick.major.pad': 1,
          'xtick.major.pad': 1,
          'text.usetex': True,
          'figure.figsize': fig_size,
          'legend.frameon': False,
          'legend.fancybox': False}
plt.rcParams.update(params)

# %%
import matplotlib as mpl
mpl.rcParams['axes.prop_cycle'] = plt.cycler("color", plt.cm.Dark2.colors)

# %%
list_L=np.array([25,50,100,200,400,800])

# %% [markdown]
# scp -r chihiro:~/Thesis/AI2D/AI2D_on_lattice/spontaneous_destab_liqphase/1box/destab_D0.1_L/* destab_D0.1_L_chihiro

# %%
td={}
for L in list_L:
    td[L]=np.array([])
#     for i in range(10):
#         try:
#             data=np.loadtxt("destab_D0.1_L/L%d/i%d/f_mag.dat"%(L,i), usecols=(0))[-1]
#             td[L].append(data)
#         except:
#             pass
    for i in range(10):
        try:
            data=np.loadtxt("destab_D0.1_L2/L%d/i%d/f_mag.dat"%(L,i), usecols=(0))
            td[L]=np.concatenate((td[L], data))
        except:
            pass

    for i in range(51):
        try:
            data=np.loadtxt("destab_D0.1_L_chihiro/L%d/i%d/f_mag.dat"%(L,i), usecols=(0))
            td[L]=np.concatenate((td[L], data))
        except:
            pass

# %%
a, b = np.polyfit(np.log(list(td)),
             np.log([np.mean(td[tau]) for tau in td]), deg=1)

# %%
plt.errorbar(list(td),
             [np.mean(td[tau]) for tau in td],
             yerr=0*np.array([np.std(td[tau]) for tau in td])/np.sqrt([len(td[tau]) for tau in td]),
             capsize=0,
             markersize=5,
             fmt='o')

ax_L=np.linspace(20,1200)
plt.loglog(ax_L, np.exp(b)*ax_L**(a), 'k--')
ax=plt.gca()
ax.loglog()

plt.xlim([20,1000])
plt.ylim(0.7e3, 8.5e6)
plt.xlabel(r'$L$', labelpad=-25, x=0.96, rotation=0, zorder=100);
plt.ylabel(r'$\tau_d$', labelpad=-28, y=0.9, rotation=0, zorder=100);

plt.text(x=120, y=0.6e5, s=r'$\propto L^{-2}$', rotation=-25)

plt.tight_layout(pad=0.01)
plt.savefig('tau_d_L2.pdf');

# %% [markdown]
# # Scaling of the destabilization time w/ $l_y$

# %%
list_ly=np.arange(1,20,1)

# %% [markdown]
# scp -r chihiro:~/Thesis/AI2D/AI2D_on_lattice/spontaneous_destab_liqphase/1box/destab_D0.1_ly/* destab_D0.1_ly_chihiro

# %%
td_1={}
for ly in list_ly:
    td_1[ly]=np.array([])
#     for i in range(21):
#         try:
#             data=np.loadtxt("destab_D0.1_ly/ly%d/i%d/f_mag.dat"%(ly,i), usecols=(0))[-1]
#             td_1[ly].append(data)
#         except:
#             pass

    for i in range(50):
        try:
            data=np.loadtxt("destab_D0.1_ly_chihiro/ly%d/i%d/f_mag.dat"%(ly,i), usecols=(0))
            td_1[ly]=np.concatenate((td_1[ly], data))
        except:
            pass
        
    print(ly, len(td_1[ly]))
# Out:
# 1 500
# 2 500
# 3 500
# 4 500
# 5 500
# 6 500
# 7 500
# 8 500
# 9 500
# 10 500
# 11 500
# 12 500
# 13 500
# 14 500
# 15 495
# 16 490
# 17 485
# 18 481
# 19 457

# %%
td_12={}
for ly in list_ly:
    td_12[ly]=np.array([])

    for i in range(50):
        try:
            data=np.loadtxt("destab_D0.12_L2/ly%d/i%d/f_mag.dat"%(ly,i), usecols=(0))
            td_12[ly]=np.concatenate((td_12[ly], data))
        except:
            pass
    
    for i in range(50):
        try:
            data=np.loadtxt("destab_D0.12_ly_chihiro/ly%d/i%d/f_mag.dat"%(ly,i), usecols=(0))
            td_12[ly]=np.concatenate((td_12[ly], data))
        except:
            pass
        
    print(ly, len(td_12[ly]))
# Out:
# 1 1000
# 2 589
# 3 80
# 4 64
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: loadtxt: Empty input file: "destab_D0.12_L2/ly3/i2/f_mag.dat"
#   import sys
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: loadtxt: Empty input file: "destab_D0.12_L2/ly3/i5/f_mag.dat"
#   import sys
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: loadtxt: Empty input file: "destab_D0.12_L2/ly3/i6/f_mag.dat"
#   import sys
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: loadtxt: Empty input file: "destab_D0.12_L2/ly3/i7/f_mag.dat"
#   import sys
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: loadtxt: Empty input file: "destab_D0.12_ly_chihiro/ly3/i3/f_mag.dat"
#
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: loadtxt: Empty input file: "destab_D0.12_ly_chihiro/ly3/i10/f_mag.dat"
#
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: loadtxt: Empty input file: "destab_D0.12_L2/ly4/i0/f_mag.dat"
#   import sys
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: loadtxt: Empty input file: "destab_D0.12_ly_chihiro/ly4/i3/f_mag.dat"
#
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: loadtxt: Empty input file: "destab_D0.12_ly_chihiro/ly4/i4/f_mag.dat"
#
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: loadtxt: Empty input file: "destab_D0.12_L2/ly5/i0/f_mag.dat"
#   import sys
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: loadtxt: Empty input file: "destab_D0.12_L2/ly5/i5/f_mag.dat"
#   import sys
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: loadtxt: Empty input file: "destab_D0.12_ly_chihiro/ly5/i1/f_mag.dat"
#
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: loadtxt: Empty input file: "destab_D0.12_ly_chihiro/ly5/i7/f_mag.dat"
#
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: loadtxt: Empty input file: "destab_D0.12_L2/ly6/i6/f_mag.dat"
#   import sys
# 5 83
# 6 88
# 7 66
# 8 77
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: loadtxt: Empty input file: "destab_D0.12_ly_chihiro/ly6/i4/f_mag.dat"
#
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: loadtxt: Empty input file: "destab_D0.12_L2/ly7/i2/f_mag.dat"
#   import sys
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: loadtxt: Empty input file: "destab_D0.12_L2/ly7/i8/f_mag.dat"
#   import sys
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: loadtxt: Empty input file: "destab_D0.12_L2/ly7/i9/f_mag.dat"
#   import sys
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: loadtxt: Empty input file: "destab_D0.12_ly_chihiro/ly7/i1/f_mag.dat"
#
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: loadtxt: Empty input file: "destab_D0.12_ly_chihiro/ly7/i10/f_mag.dat"
#
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: loadtxt: Empty input file: "destab_D0.12_L2/ly8/i5/f_mag.dat"
#   import sys
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: loadtxt: Empty input file: "destab_D0.12_L2/ly8/i8/f_mag.dat"
#   import sys
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: loadtxt: Empty input file: "destab_D0.12_ly_chihiro/ly8/i0/f_mag.dat"
#
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: loadtxt: Empty input file: "destab_D0.12_ly_chihiro/ly8/i6/f_mag.dat"
#
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: loadtxt: Empty input file: "destab_D0.12_ly_chihiro/ly9/i0/f_mag.dat"
#
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: loadtxt: Empty input file: "destab_D0.12_ly_chihiro/ly9/i4/f_mag.dat"
#
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: loadtxt: Empty input file: "destab_D0.12_ly_chihiro/ly9/i7/f_mag.dat"
#
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: loadtxt: Empty input file: "destab_D0.12_ly_chihiro/ly10/i1/f_mag.dat"
# 9 57
# 10 20
# 11 40
# 12 42
# 13 14
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: loadtxt: Empty input file: "destab_D0.12_ly_chihiro/ly10/i8/f_mag.dat"
#
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: loadtxt: Empty input file: "destab_D0.12_ly_chihiro/ly10/i9/f_mag.dat"
#
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: loadtxt: Empty input file: "destab_D0.12_ly_chihiro/ly11/i1/f_mag.dat"
#
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: loadtxt: Empty input file: "destab_D0.12_ly_chihiro/ly12/i6/f_mag.dat"
#
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: loadtxt: Empty input file: "destab_D0.12_ly_chihiro/ly12/i7/f_mag.dat"
#
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: loadtxt: Empty input file: "destab_D0.12_ly_chihiro/ly13/i3/f_mag.dat"
#
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: loadtxt: Empty input file: "destab_D0.12_ly_chihiro/ly13/i4/f_mag.dat"
# 14 18
# 15 21
# 16 12
# 17 17
# 18 11
# 19 7
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: loadtxt: Empty input file: "destab_D0.12_ly_chihiro/ly15/i3/f_mag.dat"
#
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: loadtxt: Empty input file: "destab_D0.12_ly_chihiro/ly15/i8/f_mag.dat"
#
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: loadtxt: Empty input file: "destab_D0.12_ly_chihiro/ly16/i0/f_mag.dat"
#
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: loadtxt: Empty input file: "destab_D0.12_ly_chihiro/ly16/i1/f_mag.dat"
#
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: loadtxt: Empty input file: "destab_D0.12_ly_chihiro/ly16/i3/f_mag.dat"
#
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: loadtxt: Empty input file: "destab_D0.12_ly_chihiro/ly16/i6/f_mag.dat"
#
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: loadtxt: Empty input file: "destab_D0.12_ly_chihiro/ly17/i8/f_mag.dat"
#
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: loadtxt: Empty input file: "destab_D0.12_ly_chihiro/ly17/i10/f_mag.dat"
#
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: loadtxt: Empty input file: "destab_D0.12_ly_chihiro/ly18/i0/f_mag.dat"
#
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: loadtxt: Empty input file: "destab_D0.12_ly_chihiro/ly18/i5/f_mag.dat"
#
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: loadtxt: Empty input file: "destab_D0.12_ly_chihiro/ly18/i6/f_mag.dat"
#
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: loadtxt: Empty input file: "destab_D0.12_ly_chihiro/ly18/i7/f_mag.dat"
#
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: loadtxt: Empty input file: "destab_D0.12_ly_chihiro/ly19/i0/f_mag.dat"
#
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: loadtxt: Empty input file: "destab_D0.12_ly_chihiro/ly19/i2/f_mag.dat"
#
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: loadtxt: Empty input file: "destab_D0.12_ly_chihiro/ly19/i7/f_mag.dat"

# %%
td_14={}
for ly in list_ly:
    td_14[ly]=np.array([])
#     for i in range(21):
#         try:
#             data=np.loadtxt("destab_D0.1_ly/ly%d/i%d/f_mag.dat"%(ly,i), usecols=(0))[-1]
#             td_14[ly].append(data)
#         except:
#             pass

    for i in range(50):
        try:
            data=np.loadtxt("destab_D0.14_ly_chihiro/ly%d/i%d/f_mag.dat"%(ly,i), usecols=(0))
            td_14[ly]=np.concatenate((td_14[ly], data))
        except:
            pass
        
    print(ly, len(td_14[ly]))
# Out:
# 1 210
# 2 210
# 3 0
# 4 0
# 5 0
# 6 0
# 7 0
# 8 0
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly3/i0/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly3/i2/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly3/i3/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly3/i4/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly3/i5/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly3/i7/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly3/i9/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly3/i10/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly3/i11/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly3/i13/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly3/i15/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly3/i16/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly3/i17/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly3/i18/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly3/i19/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly3/i20/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly4/i0/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly4/i2/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly4/i3/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly4/i4/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly4/i5/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly4/i6/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly4/i7/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly4/i8/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly4/i9/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly4/i10/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly4/i11/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly4/i13/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly4/i14/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly4/i16/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly4/i17/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly4/i18/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly4/i19/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly4/i20/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly5/i0/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly5/i1/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly5/i2/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly5/i3/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly5/i4/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly5/i5/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly5/i7/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly5/i8/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly5/i9/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly5/i10/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly5/i11/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly5/i12/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly5/i13/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly5/i15/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly5/i16/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly5/i17/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly5/i18/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly5/i19/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly5/i20/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly6/i0/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly6/i1/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly6/i2/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly6/i3/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly6/i4/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly6/i5/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly6/i6/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly6/i7/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly6/i9/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly6/i10/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly6/i11/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly6/i12/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly6/i13/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly6/i14/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly6/i15/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly6/i16/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly6/i17/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly6/i18/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly6/i19/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly6/i20/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly7/i0/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly7/i1/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly7/i2/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly7/i4/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly7/i5/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly7/i6/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly7/i7/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly7/i8/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly7/i9/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly7/i11/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly7/i12/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly7/i13/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly7/i14/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly7/i16/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly7/i17/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly7/i18/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly7/i20/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly8/i0/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly8/i1/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly8/i2/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly8/i3/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly8/i4/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly8/i5/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly8/i6/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly8/i7/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly8/i8/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly8/i9/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly8/i10/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly8/i11/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly8/i12/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly8/i13/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly8/i14/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly8/i15/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly8/i16/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly8/i17/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly8/i19/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly9/i0/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly9/i1/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly9/i2/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly9/i5/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly9/i6/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly9/i8/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly9/i9/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly9/i10/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly9/i11/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly9/i12/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly9/i14/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly9/i15/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly9/i16/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly9/i17/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly9/i19/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly9/i20/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly10/i0/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly10/i1/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly10/i3/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly10/i5/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly10/i6/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly10/i7/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly10/i8/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly10/i9/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly10/i10/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly10/i11/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly10/i12/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly10/i14/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly10/i15/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly10/i16/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly10/i17/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly10/i18/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly10/i19/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly10/i20/f_mag.dat"
#   del sys.path[0]
# 9 0
# 10 0
# 11 2
# 12 0
# 13 0
# 14 0
# 15 0
# 16 0
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly11/i0/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly11/i2/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly11/i3/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly11/i4/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly11/i5/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly11/i6/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly11/i7/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly11/i8/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly11/i9/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly11/i10/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly11/i11/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly11/i12/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly11/i13/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly11/i14/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly11/i16/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly11/i17/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly11/i18/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly11/i19/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly11/i20/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly12/i0/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly12/i1/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly12/i2/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly12/i3/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly12/i4/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly12/i5/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly12/i6/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly12/i7/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly12/i8/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly12/i9/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly12/i10/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly12/i11/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly12/i12/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly12/i13/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly12/i14/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly12/i15/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly12/i16/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly12/i17/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly12/i18/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly12/i19/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly12/i20/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly13/i0/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly13/i1/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly13/i2/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly13/i3/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly13/i4/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly13/i5/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly13/i6/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly13/i7/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly13/i8/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly13/i10/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly13/i11/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly13/i12/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly13/i13/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly13/i14/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly13/i15/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly13/i16/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly13/i17/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly13/i19/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly13/i20/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly14/i0/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly14/i1/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly14/i2/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly14/i3/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly14/i4/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly14/i5/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly14/i6/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly14/i7/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly14/i8/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly14/i9/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly14/i10/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly14/i11/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly14/i12/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly14/i13/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly14/i14/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly14/i15/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly14/i16/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly14/i17/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly14/i18/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly14/i19/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly14/i20/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly15/i0/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly15/i1/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly15/i3/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly15/i4/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly15/i6/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly15/i7/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly15/i9/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly15/i10/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly15/i12/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly15/i13/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly15/i14/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly15/i15/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly15/i16/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly15/i17/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly15/i19/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly15/i20/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly16/i0/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly16/i1/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly16/i2/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly16/i3/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly16/i4/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly16/i5/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly16/i6/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly16/i7/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly16/i8/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly16/i9/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly16/i10/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly16/i11/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly16/i12/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly16/i13/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly16/i14/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly16/i15/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly16/i16/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly16/i17/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly16/i18/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly16/i19/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly16/i20/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly17/i0/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly17/i1/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly17/i2/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly17/i3/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly17/i4/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly17/i5/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly17/i6/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly17/i7/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly17/i8/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly17/i9/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly17/i11/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly17/i12/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly17/i13/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly17/i14/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly17/i15/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly17/i16/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly17/i17/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly17/i18/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly17/i19/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly17/i20/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly18/i0/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly18/i1/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly18/i2/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly18/i3/f_mag.dat"
#   del sys.path[0]
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: loadtxt: Empty input file: "destab_D0.14_ly_chihiro/ly18/i4/f_mag.dat"
#   del sys.path[0]
# 17 0
# 18 0
# 19 0

# %%
plt.plot([], [])
# plt.errorbar(list(td_1),
#              [np.mean(td_1[tau]) for tau in td_1],
#              yerr=3*np.array([np.std(td_1[tau]) for tau in td_1])/np.sqrt([len(td_1[tau]) for tau in td_1]),
#              capsize=0,
#              fmt='o',
#             label=r'$D=0.10$')

plt.plot(np.array(list(td_1)),
             np.array(list(td_1))*np.array([np.mean(td_1[tau]) for tau in td_1]),
             'o',
            label=r'$D=0.10$')

plt.errorbar(np.array(list(td_12)),
             np.array(list(td_12))*np.array([np.mean(td_12[tau]) for tau in td_12]),
             yerr=3*np.array(list(td_12))*np.array([np.std(td_12[tau]) for tau in td_12])/np.sqrt([len(td_12[tau]) for tau in td_12]),
             capsize=2,
             fmt='o',
            label=r'$D=0.12$')

plt.errorbar(np.array(list(td_14)),
             np.array(list(td_14))*np.array([np.mean(td_14[tau]) for tau in td_14]),
             yerr=3*np.array(list(td_14))*np.array([np.std(td_14[tau]) for tau in td_14])/np.sqrt([len(td_14[tau]) for tau in td_14]),
             capsize=2,
             fmt='o',
            label=r'$D=0.14$')


plt.semilogy()
plt.legend()

plt.xlabel(r'$l_y$', labelpad=-26, x=0.96, rotation=0, zorder=100);
plt.ylabel(r'$l_y\tau_d$', labelpad=-32, y=0.88, rotation=0, zorder=100);

plt.tight_layout(pad=0.01)
plt.savefig('tau_d_ly.pdf');
# Out:
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:217: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:186: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:209: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# # Spontaneous destab snapshot

# %%
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

# %%
L=10000

# %%
df_m=pd.read_parquet('../1box_film_destab/destab_film_D0.1_largeL/i1/f_profiles_m.parquet')
# Out:
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/fastparquet/dataframe.py:5: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
#   from pandas.core.index import CategoricalIndex, RangeIndex, Index, MultiIndex

# %%
fig_width_pt = 246  # Get this from LaTeX using \showthe\columnwidth
                      # For PRL columnwidth is 246pt.
golden_mean = (np.sqrt(5)+1.0)/2.0         # Aesthetic ratio

fig_height_pt = fig_width_pt/3
inches_per_pt = 1.0/72.27               # Convert pt to inch
fig_width = fig_width_pt*inches_per_pt  # width in inches
fig_height = fig_height_pt*inches_per_pt      # height in inches
fig_size =  [fig_width,fig_height]
params = {'backend': 'ps',
          'axes.labelsize': 10,
          'font.size': 10,
          'xtick.labelsize': 7,
          'xtick.direction': 'out',
          'ytick.labelsize': 7,
          'ytick.direction': 'out',
          'ytick.major.pad': 1,
          'xtick.major.pad': 1,
          'text.usetex': True,
          'figure.figsize': fig_size,
          'legend.frameon': False,
          'legend.fancybox': False}
plt.rcParams.update(params)

# %%
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap


top = cm.get_cmap('PuBu_r', 128)
bottom = cm.get_cmap('YlOrBr', 128)
middle = (1,1,1,1)
newcolors = np.vstack((top(np.linspace(0, 1, 20)),
                       bottom(np.linspace(0, 1, 128))))
newcmp = ListedColormap(newcolors, name='OrangeBlue')

# %%
kt=1570
t0=np.unique(df_m.t)[kt]
X_m=-np.roll(df_m[df_m.t==t0].drop(columns=['t']), axis=0, shift=10)[:,7400:8700]

pcm=plt.imshow(X_m[:,::-1], cmap=newcmp, aspect='auto', vmin=-9, vmax=60, origin='lower')

inset_ax = inset_axes(plt.gca(),
                          height="61%", # set height
                          width="2.54%", # and width
                          loc=7,
                          #bbox_to_anchor=(75,130, 100, 100)
                     )

cbar=plt.colorbar(pcm, fraction=0.1, ticks=[-5, 0, +5], cax = inset_ax, 
                  orientation='vertical',
                    drawedges=False)

cbar.outline.set_visible(False)
cbar.ax.tick_params(size=1, color='w')
cbar_yticks = plt.getp(cbar.ax.axes, 'yticklabels')
plt.setp(cbar_yticks, color='w')

cbar.ax.set_ylabel(r'$m$', rotation=0, labelpad=-14, y=1.3, color="w")
plt.tight_layout(pad=0.01)

plt.savefig('spontaneous_micro.pdf', dpi=400);
# Out:
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %%
fig, ax = plt.subplots(figsize=(14, 4))

kt=1490
t0=np.unique(df_m.t)[kt]
v0=10
X_m=np.roll(df_m[df_m.t==t0].drop(columns=['t']), axis=0, shift=10)
img=plt.imshow(X_m, cmap='PiYG', vmin=-v0, vmax=v0, aspect="auto")

plt.xlim(7400,8900)
cbar = plt.colorbar(img)
cbar.set_label('Magnetization')
np.min(X_m[X_m<0])
# Out:
# -56.0

# %%
np.max(X_m)
# Out:
# 28.0

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

# %%
ly=60
lx=300

# %%
prof_destab=pd.read_csv('f_profiles.dat', sep=' ', names=np.arange(lx), index_col=False)
mag=pd.read_csv('f_mag.dat', sep=' ', names=['t', 'M'], index_col=False)
plt.plot(mag.t, mag.M, '-')

# %%
k=1
plt.matshow((prof_destab.values[k*ly:(k+1)*ly,:]), cmap='PiYG', vmin=3, vmax=-3)
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-775-301343d4f752> in <module>
#       1 k=1
# ----> 2 plt.matshow((prof_destab.values[k*ly:(k+1)*ly,:]), cmap='PiYG', vmin=3, vmax=-3)
#       3 plt.colorbar()
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in matshow(A, fignum, **kwargs)
#    2186         # Extract actual aspect ratio of array and make appropriately sized
#    2187         # figure.
# -> 2188         fig = figure(fignum, figsize=figaspect(A))
#    2189         ax = fig.add_axes([0.15, 0.09, 0.775, 0.775])
#    2190     im = ax.matshow(A, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in figaspect(arg)
#    2750
#    2751     # New size for the figure, keeping the aspect ratio of the caller
# -> 2752     newsize = np.array((fig_height / arr_ratio, fig_height))
#    2753
#    2754     # Sanity checks, don't drop either dimension below figsize_min
#
# ZeroDivisionError: float division by zero

# %%
m=pd.read_csv('f_bands_m.dat', sep=' ', names=np.arange(lx), index_col=False).values
rho=pd.read_csv('f_bands_rho.dat', sep=' ', names=np.arange(lx), index_col=False).values

# %%
k=-1
plt.plot(m[k,:])
plt.plot(rho[k,:])

# %% [markdown]
# # $p_{rev}(h0)$

# %%
import subprocess

# %%
def rev(h0, beta=2, v=1, D=1):
    with open('f_input.dat', 'w') as f:
        f.write('tgap = 100 tmax = 100 rho0 = 5 lx = 100 ly = 20 w0 = 1 beta = %f v = %f D = %f h0 = %f'%(beta, v, D, h0))
        
    bashCommand = "./activeIsing"
    popen = subprocess.Popen(bashCommand, stdout=subprocess.PIPE)
    popen.wait()
    output = popen.stdout.read()
    return(np.loadtxt('f_mag.dat'))

# %%
sample_rev={}
for h0 in np.linspace(10,150,10):
    print(h0)
    sample_rev[h0]=rev(h0, beta=2, v=1, D=1)
# Out:
# 10.0
# 25.555555555555557
# 41.111111111111114
# 56.666666666666664
# 72.22222222222223
# 87.77777777777777
# 103.33333333333333
# 118.88888888888889
# 134.44444444444446
# 150.0

# %%
p_rev=[np.mean(np.array(sample_rev[s])>0.05) for s in sample_rev]

# %%
plt.plot(5*np.linspace(10,150,10), p_rev, 'o')
plt.xlabel('Fluctuation size')
plt.ylabel('Probability of reversal')
# Out:
# Text(0, 0.5, 'Probability of reversal')

# %% [markdown]
# # $p_{rev}(\beta)$

# %%
import subprocess

# %%
def rev(h0, beta=2, v=1, D=1):
    with open('f_input.dat', 'w') as f:
        f.write('tgap = 100 tmax = 100 rho0 = 5 lx = 100 ly = 20 w0 = 1 beta = %f v = %f D = %f h0 = %f'%(beta, v, D, h0))
        
    bashCommand = "./activeIsing"
    popen = subprocess.Popen(bashCommand, stdout=subprocess.PIPE)
    popen.wait()
    output = popen.stdout.read()
    return(np.loadtxt('f_mag.dat'))

# %%
list_beta=np.arange(1.2, 3.7, 2)
list_h0=np.arange(10, 150, 10)

# %%
sample_rev_beta={}

for beta in list_beta:
    sample_rev_beta[beta]={}
    for h0 in list_h0:
# Out:
# 10.0
# 25.555555555555557
# 41.111111111111114
# 56.666666666666664
# 72.22222222222223
# 87.77777777777777
# 103.33333333333333
# 118.88888888888889
# 134.44444444444446
# 150.0

# %%
sample_rev
#         0.100056, 0.100444, 0.101278, 0.100333, 0.100611, 0.100333,
#         0.101   , 0.100722, 0.100278, 0.101   , 0.102889, 0.101389,
#         0.100722, 0.100444, 0.1015  , 0.100444, 0.100111, 0.100778,
#         0.1     , 0.101167, 0.100222, 0.100056, 0.1005  , 0.1005  ,
#         0.100389, 0.100111, 0.1     , 0.101167, 0.100333, 0.1     ,
#         0.101056, 0.100333, 0.102056, 0.100389]),
#  134.44444444444446: array([0.100833, 0.100444, 0.100278, 0.100611, 0.101056, 0.100833,
#         0.101889, 0.100556, 0.100056, 0.101111, 0.100389, 0.101333,
#         0.100778, 0.100444, 0.100222, 0.101722, 0.100167, 0.102667,
#         0.100944, 0.1     , 0.100611, 0.100944, 0.1005  , 0.100444,
#         0.100056, 0.100778, 0.101944, 0.1     , 0.101778, 0.1005  ,
#         0.100167, 0.100167, 0.101778, 0.101   , 0.100667, 0.100944,
#         0.100056, 0.100333, 0.100611, 0.100778, 0.100222, 0.100111,
#         0.100333, 0.1025  , 0.100611, 0.101222, 0.101   , 0.103833,
#         0.100667, 0.100333, 0.1005  , 0.1     , 0.100444, 0.100222,
#         0.100778, 0.100056, 0.101389, 0.100111, 0.100333, 0.100611,
#         0.100667, 0.100278, 0.100667, 0.100167, 0.100556, 0.101167,
#         0.100889, 0.100111, 0.101444, 0.100222, 0.101222, 0.1     ,
#         0.100556, 0.100389, 0.102333, 0.101333, 0.1     , 0.100778,
#         0.100944, 0.100667, 0.100167, 0.100611, 0.100389, 0.102222,
#         0.101   , 0.102167, 0.1     , 0.102444, 0.102167, 0.101   ,
#         0.100722, 0.100611, 0.1     , 0.100222, 0.100111, 0.100611,
#         0.1     , 0.100056, 0.101889, 0.100111]),
#  150.0: array([0.100556, 0.100056, 0.101056, 0.100833, 0.100667, 0.101056,
#         0.102056, 0.100333, 0.100111, 0.100056, 0.100556, 0.100833,
#         0.100444, 0.100833, 0.100444, 0.100556, 0.103   , 0.100667,
#         0.100111, 0.100222, 0.100167, 0.101333, 0.101278, 0.100333,
#         0.100611, 0.100389, 0.100444, 0.100833, 0.100889, 0.100167,
#         0.100556, 0.100333, 0.100056, 0.100167, 0.101333, 0.101611,
#         0.100556, 0.100611, 0.100056, 0.100167, 0.100333, 0.1     ,
#         0.100278, 0.100222, 0.102   , 0.101222, 0.101667, 0.102333,
#         0.103167, 0.100278, 0.100167, 0.102389, 0.100778, 0.100278,
#         0.103444, 0.100056, 0.100278, 0.100556, 0.100111, 0.101278,
#         0.100278, 0.100556, 0.100167, 0.101722, 0.100167, 0.100278,
#         0.100278, 0.101056, 0.100389, 0.1     , 0.101944, 0.100444,
#         0.100278, 0.100167, 0.100167, 0.100333, 0.100056, 0.102556,
#         0.100278, 0.1     , 0.101   , 0.1     , 0.1005  , 0.101278,
#         0.100722, 0.100444, 0.101167, 0.101611, 0.100667, 0.100389,
#         0.101167, 0.100889, 0.100722, 0.100222, 0.101889, 0.101   ,
#         0.102333, 0.100667, 0.101333, 0.1     ])}

# %%
p_rev=[np.mean(np.array(sample_rev[s])>0.05) for s in sample_rev]

# %%
plt.plot(5*np.linspace(10,150,10), p_rev, 'o')
plt.xlabel('Fluctuation size')
plt.ylabel('Probability of reversal')
# Out:
# Text(0, 0.5, 'Probability of reversal')

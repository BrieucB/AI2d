# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
import matplotlib.animation as animation

# %%
mag=pd.read_csv('f_mag.dat', sep=' ', names=['t', 'M'])
plt.plot(mag.t, mag.M, '-')

# %%
min_mag=[np.min(df[df.t==t0].drop(columns=['t',]).values) for t0 in np.unique(pd.to_numeric(df.t, errors='coerce'))]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e6db360a061f> in <module>
# ----> 1 min_mag=[np.min(df[df.t==t0].drop(columns=['t',]).values) for t0 in np.unique(pd.to_numeric(df.t, errors='coerce'))]
#
# NameError: name 'df' is not defined

# %%
plt.plot(min_mag)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-bb837fd9cb1c> in <module>
# ----> 1 plt.plot(min_mag)
#
# NameError: name 'min_mag' is not defined

# %%
np.argsort(min_mag)[:10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-d66e2de3a45e> in <module>
# ----> 1 np.argsort(min_mag)[:10]
#
# NameError: name 'min_mag' is not defined

# %%
df=pd.read_csv('aster_longrun/D0.05/f_profiles.dat', sep=' ', names=['t']+[str(a) for a in np.arange(100)], index_col=False)

# %%
kt=10
v0=np.min(df.values)/2
t0=np.unique(pd.to_numeric(df.t, errors='coerce'))[kt]
print(t0)
X=df[df.t==t0].drop(columns=['t',])

cmap = plt.get_cmap('PiYG')
#cmap.set_under('black')

plt.imshow(X, cmap=cmap, vmin=-v0, vmax=v0)
cbar = plt.colorbar()


plt.title(r'$t=%f$'%t0, pad=20)
# Out:
# 1000.12
# Text(0.5, 1.0, '$t=1000.120000$')

# %%
fig, ax = plt.subplots()
cmap = plt.get_cmap('PiYG')

kt=0
t0=np.unique(df.t)[kt]

X_m=df[df.t==t0].drop(columns=['t'])

im = plt.imshow(X_m, cmap=cmap, vmin=-v0, vmax=v0)
plt.colorbar()
plt.title(r'$t=%f$'%t0, pad=20)

def update(*args):
    global kt

    t0=np.unique(df.t)[kt]
    X_m=df[df.t==t0].drop(columns=['t'])
    
    im.set_array(X_m)
    plt.title(r'$t=%f$'%t0, pad=20)
    
    kt += 1

    return im,

ani = animation.FuncAnimation(fig, update, np.unique(df.t).shape[0]-2)
writer = animation.ImageMagickFileWriter(fps=20)
ani.save('spontaneous_revs_D0.05_beta2_rho15_eps0.8.mp4', writer=writer)

# %% [markdown]
# # Spontaneous reversals

# %%
i_rev_list=[]
for i in range(100):
    try:
        mag=pd.read_csv('destab_eps1/i%d/f_mag.dat'%(i), sep=' ', names=['t', 'M'])
        i_rev_list.append(i)
    except:
        pass

# %%
i_rev_list
# Out:
# [0, 1, 3, 5, 7, 28, 30]

# %%
list_td=[]
for i in i_rev_list:
    mag=pd.read_csv('destab_eps1/i%d/f_mag.dat'%(i), sep=' ', names=['t', 'M'])
    list_td.append(mag.t[np.where(mag.M<0.5)[0][0]])
# Out:
# ---------------------------------------------------------------------
# IndexError                          Traceback (most recent call last)
# <ipython-input-240-d4b8f2a5ee6a> in <module>
#       2 for i in i_rev_list:
#       3     mag=pd.read_csv('destab_eps1/i%d/f_mag.dat'%(i), sep=' ', names=['t', 'M'])
# ----> 4     list_td.append(mag.t[np.where(mag.M<0.5)[0][0]])
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
len(list_td)
# Out:
# 7

# %%
np.mean(list_td)
# Out:
# 10.204741999999998

# %%
i=28
L=100
#df_m=pd.read_csv('destab_eps1/i%d/f_profiles.dat'%(i), sep=' ', names=['t']+[str(a) for a in np.arange(L)], index_col=False, dtype=np.float64)
mag=pd.read_csv('destab_eps1/i%d/f_mag.dat'%(i), sep=' ', names=['t', 'M'])

# %%
plt.plot(mag.t, mag.M, '-')
#plt.xlim(mag.t.values[-1]-10000, mag.t.values[-1])

# %%
kt=-2
t0=np.unique(df_m.t)[kt]
v0=10
X_m=df_m[df_m.t==t0].drop(columns=['t'])
print(t0, np.sum(X_m.values)/(5*100*100))
img=plt.matshow(X_m, cmap='PiYG', vmin=-v0, vmax=v0)

cbar = plt.colorbar(img)
cbar.set_label('Magnetization')
# Out:
# 1999800.04 1.95376

# %%
kt=50
t0=np.unique(df_m.t)[kt]
X_rho=df_rho[df_rho.t==t0].drop(columns=['t'])
plt.matshow(X_rho)

cbar = plt.colorbar()
cbar.set_label('Density')

# %%
fig, ax = plt.subplots(figsize=(4, 4))

v0=10

kt=600
t0=np.unique(df_m.t)[kt]

X_m=df_m[df_m.t==t0].drop(columns=['t'])

im = plt.imshow(X_m, cmap='PiYG', vmin=-v0, vmax=v0)
plt.colorbar()

def update(*args):
    global kt

    t0=np.unique(df_m.t)[kt]
    X_m=df_m[df_m.t==t0].drop(columns=['t'])
    
    im.set_array(X_m)

    kt += 1

    return im,

ani = animation.FuncAnimation(fig, update, 200)
writer = animation.ImageMagickFileWriter(fps=20)
ani.save('rev3.gif', writer=writer)

# %%
for i in

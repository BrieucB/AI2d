# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal

# %%
list_beta=[2.5, 2.2, 2.0, 1.8, 1.6, 1.5, 1.4, 1.3, 1.2, 1.1]

# %%
mag={}
for beta in list_beta:
    mag[beta]=np.loadtxt('instances_beta/beta%s/f_mid_mag.dat'%str(beta))

# %%
for beta in list_beta[:-1]:
    dt=(2+1+np.exp(beta))**(-1)
    plt.plot(dt*np.arange(0, mag[beta].shape[0]), mag[beta]-np.mean(mag[beta]), label=beta)
plt.legend()
# Out:
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.plot(mag[1.2])

# %%
for beta in list_beta[5:6]:
    plt.plot(mag[beta], label=beta)
plt.legend()

# %% [markdown]
# # Crossing zero

# %%
v=[]
for beta in list_beta:
    m=mag[beta]
    th=np.mean(m)
    t0=np.where((m>=th)&(np.roll(m,-1)<=th))
    dt=(2+1+np.exp(beta))**(-1)
    v.append(400/(dt*np.mean(np.diff(t0))))

# %%
v
# Out:
# [1.0972983258255289,
#  1.1023805385326053,
#  1.1008578329388472,
#  1.091781488035469,
#  1.0717103850626675,
#  1.0578563549435227,
#  1.04145400377816,
#  1.0263501626490215,
#  0.9990587355988444,
#  53.86915311204277]

# %%
plt.plot(1/np.array(list_beta)[:-1], v[:-1], 'o')
#plt.ylim(0,2)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
list_D=np.round(np.arange(0.4, 2.6, 0.1), decimals=1)

# %%
data={}
mag={}
for D in list(list_D):
    tmp=pd.read_csv('avg_prof_D/D%s/f_bands.dat'%D, sep=' ', names=['t', 'm', 'rho'])
    
    s=tmp.shape[0]
    data[D]=np.reshape(tmp.rho.values[:400*(s//400)], (-1, 400))
    mag[D]=np.sum(np.reshape(tmp.m.values[:400*(s//400)], (-1, 400)), axis=1)
    print(D, data[D].shape[0])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-335fe215ab1b> in <module>
#       2 mag={}
#       3 for D in list(list_D):
# ----> 4     tmp=pd.read_csv('avg_prof_D/D%s/f_avg_prof.dat'%D, sep=' ', names=['t', 'm', 'rho'])
#       5
#       6     s=tmp.shape[0]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File avg_prof_D/D0.4/f_avg_prof.dat does not exist: 'avg_prof_D/D0.4/f_avg_prof.dat'

# %%
D=0.5
plt.plot(mag[D])

# %%
plt.plot(data[D][950:1000:10,:].T)

# %%
x1={}
x2={}
dx={}

for D in list_D:
    th=np.max(data[D][-1,:])/2
    print(th)
    
    t0, x0 = np.where((data[D]<=th)&(np.roll(data[D],-5, axis=1)>=th))
    x1[D]=x0[np.unique(t0, return_index=True)[1]]

    t0, x0 = np.where((data[D]>=th)&(np.roll(data[D],-5, axis=1)<th))
    x2[D]=x0[np.unique(t0, return_index=True)[1]]

    dx[D]=[]
    for t in range(data[D].shape[0]):
        if x2[D][t]>x1[D][t]:
            dx[D].append(np.int64(0.5*(x2[D][t]+x1[D][t]-400)))
        else:
            dx[D].append(np.int64(0.5*(x2[D][t]+x1[D][t])))

    dx[D]=np.array(dx[D])
# Out:
# 1.485
# 1.255
# 1.195
# 1.105
# 1.085
# 1.01
# 1.005
# 0.98
# 0.95
# 0.915
# 0.91
# 0.88
# 0.87
# 0.81
# 0.815
# 0.82
# 0.815
# 0.785
# 0.775
# 0.79
# 0.73
# 0.74
# 0.635
# 0.595
# 0.52
# 0.585
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-7531bf112459> in <module>
#       4
#       5 for D in list_D:
# ----> 6     th=np.max(data[D][-1,:])/2
#       7     print(th)
#       8
#
# KeyError: 5.0

# %%
D=5
for t in range(950, 1000, 10):
    plt.plot(np.roll(data[D][t, :], -dx[D][t])) 
    #plt.plot(data[D][t, :])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-cd41e7c6dd94> in <module>
#       1 D=5
#       2 for t in range(950, 1000, 10):
# ----> 3     plt.plot(np.roll(data[D][t, :], -dx[D][t]))
#       4     #plt.plot(data[D][t, :])
#
# KeyError: 5

# %%
D=0.4
#plt.plot(0.5*(x1[D]+x2[D]-2*dx[D]))
plt.plot(x1[D], 'o', label='x1')
plt.plot(x2[D], 'o', label='x2')
#plt.plot(dx[D])

plt.legend()

plt.xlim(400,500)
# Out:
# (400, 500)

# %%
avg_prof={}
for D in list_D:
    if D==0.5:
        avg_prof[D]=np.mean([np.roll(data[D][t, :], 
                                 -dx[D][t]) 
                         for t in range(950, 1000) 
                         if x2[D][t]>x1[D][t]+50]
                            , axis=0)
    else: 
        avg_prof[D]=np.mean([np.roll(data[D][t, :], 
                                 -dx[D][t]) 
                         for t in range(200, 600) 
                         if x2[D][t]>x1[D][t]+50]
            , axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-1937245e96f7> in <module>
#      10         avg_prof[D]=np.mean([np.roll(data[D][t, :],
#      11                                  -dx[D][t])
# ---> 12                          for t in range(200, 600)
#      13                          if x2[D][t]>x1[D][t]+50]
#      14             , axis=0)
#
# <ipython-input-22-1937245e96f7> in <listcomp>(.0)
#      11                                  -dx[D][t])
#      12                          for t in range(200, 600)
# ---> 13                          if x2[D][t]>x1[D][t]+50]
#      14             , axis=0)
#
# KeyError: 5.0

# %%
for D in list_D:
    plt.plot(avg_prof[D], label=D)

    
    plt.legend()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-69af50716d9a> in <module>
#       1 for D in list_D:
# ----> 2     plt.plot(avg_prof[D], label=D)
#       3
#       4
#       5     plt.legend()
#
# KeyError: 5.0

# %%
rhol0={}
rhog0={}

for D in list_D:
    rhol0[D]=np.mean(avg_prof[D][170:230])
    rhog0[D]=np.mean(np.roll(avg_prof[D], 200)[180:220])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-16c8aab3c3bc> in <module>
#       3
#       4 for D in list_D:
# ----> 5     rhol0[D]=np.mean(avg_prof[D][170:230])
#       6     rhog0[D]=np.mean(np.roll(avg_prof[D], 200)[180:220])
#       7
#
# KeyError: 5.0

# %%
u=list(rhol0)
plt.plot([rhol0[D] for D in u], u, 'o')
plt.plot([rhog0[D] for D in u], u, 'o')

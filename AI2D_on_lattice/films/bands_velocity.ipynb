# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal

# %%
list_beta=[1.1, 1.2, 1.4, 1.6, 1.9, 2.3, 2.5, 3.0]

# %%
mag={}
for beta in list_beta:
    mag[beta]=np.loadtxt('instances_beta/beta%s/f_mid_mag.dat'%str(beta))
# Out:
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: loadtxt: Empty input file: "instances_beta/beta1.1/f_mid_mag.dat"
#   This is separate from the ipykernel package so we can avoid doing imports until
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: loadtxt: Empty input file: "instances_beta/beta1.2/f_mid_mag.dat"
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
for beta in list_beta:
    dt=(4+np.exp(beta))**(-1)
    plt.plot(dt*np.arange(0, mag[beta].shape[0]), mag[beta]-np.mean(mag[beta]), label=beta)
plt.legend()
# Out:
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
plt.plot(mag[1.2])

# %%
for beta in list_beta[5:6]:
    plt.plot(mag[beta], label=beta)
plt.legend()

# %% [markdown]
# # Crossing zero

# %%
v=[]
for beta in list_beta:
    m=mag[beta]
    th=np.mean(m)
    t0=np.where((m>=th)&(np.roll(m,-1)<=th))
    dt=(4+np.exp(beta))**(-1)
    v.append(400/(dt*np.mean(np.diff(t0))))
# Out:
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /users/invites/benvegnen/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
v
# Out:
# [nan,
#  nan,
#  1.7811387433597956,
#  1.8446548726475975,
#  1.8717082660538789,
#  1.9369242968019431,
#  1.934492930920322,
#  1.897370465950581]

# %%
plt.plot(1/np.array(list_beta), v, 'o')
#plt.ylim(0,2)
